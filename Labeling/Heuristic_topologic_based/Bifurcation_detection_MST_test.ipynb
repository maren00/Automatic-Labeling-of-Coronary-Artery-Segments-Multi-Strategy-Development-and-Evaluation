# %% [markdown]
# ## **Detcting bifurcations using graph created with MST**

# %% [markdown]
# The following code takes the centerline points extracted by Materialise Mimics in .txt format as input, converts them to graph nodes, and links them using the Minimum Spanning Tree algorithm.
#
# It also identifies the graph's branches and assigns different labels to them by finding supersegments. It is one of the firts approaches tried, it does not provide the final labeling.
#
# It uses a data frame to store the information.

# %% [markdown]
# ### **Imports**

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from collections import defaultdict
import plotly.graph_objects as go
import networkx as nx
from scipy.spatial.distance import cdist
from scipy.spatial import distance_matrix

# %% [markdown]
# ### **Google Drive connection**

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Upload files**

# %% [markdown]
# ##### Normal 1

# %%
file_path_rca_n1= '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Normal_1/rca_centerline.txt'
file_path_lca_n1= '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Normal_1/lca_centerline.txt'

# %% [markdown]
# ##### Normal 7

# %%
file_path_rca_n7 = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Normal_7/rca_centerline.txt'
file_path_lca_n7 = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Normal_7/lca_centerline.txt'

# %% [markdown]
# ##### Diseased 7

# %%
file_path_rca_d7 = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Diseased_7/rca_centerline.txt'
file_path_lca_d7 = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Diseased_7/lca_centerline.txt'

# %% [markdown]
# ##### Diseased 9

# %%
file_path_rca_d9 = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Diseased_9/rca_centerline.txt'
file_path_lca_d9 = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/ASOCA 4 Cases Mimics/Diseased_9/lca_centerline.txt'

# %% [markdown]
# ### **Functions**

# %%
def parse_and_export_centerlines(file_path):
    branches = defaultdict(list)  # Diccionario donde la clave es el ID de la rama
    current_branch = None  # Guarda el ID de la rama actual
    has_branches = False  # Bandera para detectar si hay múltiples ramas

    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()

            # Detectar una nueva rama
            branch_match = re.match(r"\[New Branch Set\] Branch Segment (\d+):", line)
            if branch_match:
                current_branch = int(branch_match.group(1))
                has_branches = True  # Confirmamos que hay múltiples ramas
                continue

            # Si no hay identificadores de rama, asignamos un ID por defecto
            if current_branch is None:
                current_branch = 0

            # Extraer puntos de la rama actual (ignorar líneas vacías o encabezados)
            if re.match(r"^\s*-?\d+\.\d+", line):
                data = []
                for value in line.split():
                    try:
                        data.append(float(value))  # Convertir a float
                    except ValueError:
                        data.append(None)  # Manejar valores no numéricos como None
                branches[current_branch].append(data)

    # Crear lista de datos para el DataFrame
    all_data = []
    for branch_id, points in branches.items():
        for point in points:
            all_data.append([branch_id] + point)

    # Columnas según el formato esperado
    columns = ["Branch ID", "Px", "Py", "Pz", "Tx", "Ty", "Tz", "Nx", "Ny", "Nz",
               "BNx", "BNy", "BNz", "Dfit", "Dmin", "Dmax", "C", "Dh", "Xh", "Scf", "Area", "E"]

    # Crear DataFrame y retornarlo
    df = pd.DataFrame(all_data, columns=columns)

    return df

# %%
def visualize_graph(G, title='Coronary Artey Graph'):
    # Obtener las posiciones de los nodos
    pos = nx.get_node_attributes(G, 'pos')

    # Check if pos is empty
    if not pos:
        print("No positions found in the graph. Check if nodes have 'pos' attribute.")
        return

    # Crear listas para nodos y aristas
    node_x = []
    node_y = []
    node_z = []
    for p in pos.values():
        node_x.append(p[0])
        node_y.append(p[1])
        node_z.append(p[2])

    edge_x = []
    edge_y = []
    edge_z = []
    for edge in G.edges():
        # Check if node IDs are in pos before accessing them
        if edge[0] in pos and edge[1] in pos:
            x0, y0, z0 = pos[edge[0]]
            x1, y1, z1 = pos[edge[1]]
            edge_x.extend([x0, x1, None])
            edge_y.extend([y0, y1, None])
            edge_z.extend([z0, z1, None])
        else:
            print(f"Skipping edge {edge} as one or both nodes are missing position data.")

    # Crear la visualización interactiva con Plotly
    fig = go.Figure()

    # Agregar aristas
    fig.add_trace(go.Scatter3d(
        x=edge_x, y=edge_y, z=edge_z,
        mode='lines',
        line=dict(color='blue', width=3),
        name='Aristas'
    ))

    # Agregar nodos
    fig.add_trace(go.Scatter3d(
        x=node_x, y=node_y, z=node_z,
        mode='markers',
        marker=dict(size=3, color='red'),
        name='Nodos'
    ))

    # Configurar la visualización
    fig.update_layout(
        title=title,
        scene=dict(
            xaxis=dict(title='Px', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            yaxis=dict(title='Py', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            zaxis=dict(title='Pz', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            aspectmode='data'  # Asegura proporciones correctas entre los ejes
        ),
        margin=dict(l=10, r=10, b=10, t=50),
        height=800  # Aumentar el tamaño del gráfico
    )

    fig.show()

# %%
def visualize_segments(df):
    # Get unique branch IDs
    unique_branches = df['Branch ID'].unique()
    colors = np.linspace(0, 1, len(unique_branches))  # Generate color indices
    color_map = dict(zip(unique_branches, colors))  # Map each branch to a color

    # Create figure
    fig = go.Figure()

    for branch_id in unique_branches:
        branch_data = df[df['Branch ID'] == branch_id]

        fig.add_trace(go.Scatter3d(
            x=branch_data['Px'],
            y=branch_data['Py'],
            z=branch_data['Pz'],
            mode='markers',
            marker=dict(size=3, color=color_map[branch_id], colorscale='viridis'),
            name=f'Branch {branch_id}'
        ))

    # Configure layout
    fig.update_layout(
        title='Segmented Coronary Artery Visualization',
        scene=dict(
            xaxis=dict(title='Px', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            yaxis=dict(title='Py', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            zaxis=dict(title='Pz', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            aspectmode='data'  # Maintain aspect ratio
        ),
        margin=dict(l=10, r=10, b=10, t=50),
        height=800  # Set figure height
    )

    fig.show()

# %%
def clean_dataframe(df):

    columns_to_drop = [
        'Branch ID',
        'Tx', 'Ty', 'Tz',
        'C',
        'Nx', 'Ny', 'Nz',  # Normal vector coordinates
        'BNx', 'BNy', 'BNz',  # Binormal vector coordinates
        'Dfit', 'Dmin', 'Dmax',  # Circle diameters
        'Dh', 'Xh',  # Hydraulic properties
        'Scf', 'Area', 'E'  # Sectional properties and ellipticity
    ]

    # Drop columns
    df = df.drop(columns=columns_to_drop, errors='ignore')

    # Drop duplicate rows
    df = df.drop_duplicates()

    return df

# %%
def calculate_mst(df):

    # Extract the coordinates of the points
    positions = df[['Px', 'Py', 'Pz']].values

    # Calculate the Euclidean distance matrix between all points
    dist_matrix = distance_matrix(positions, positions)

    # Create a graph with all nodes and distances as weights
    G = nx.Graph()
    num_nodes = len(positions)
    for i in range(num_nodes):
        for j in range(i + 1, num_nodes):
            G.add_edge(i, j, weight=dist_matrix[i, j])

    # Get the Minimum Spanning Tree (MST)
    MST = nx.minimum_spanning_tree(G)

    return MST

# %%
def visualize_mst(df, MST):

    # Extract the positions of the nodes
    positions = df[['Px', 'Py', 'Pz']].values

    # Get the positions for the nodes
    pos = {i: positions[i] for i in range(len(positions))}

    # Create lists for node and edge coordinates
    node_x, node_y, node_z = zip(*positions)

    edge_x = []
    edge_y = []
    edge_z = []
    for edge in MST.edges():
        x0, y0, z0 = pos[edge[0]]
        x1, y1, z1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])
        edge_z.extend([z0, z1, None])

    # Create the interactive visualization with Plotly
    fig = go.Figure()

    # Add edges (aristas)
    fig.add_trace(go.Scatter3d(
        x=edge_x, y=edge_y, z=edge_z,
        mode='lines',
        line=dict(color='blue', width=2),
        name='Edges'
    ))

    # Add nodes (nodos)
    fig.add_trace(go.Scatter3d(
        x=node_x, y=node_y, z=node_z,
        mode='markers',
        marker=dict(size=3, color='red'),
        name='Nodes'
    ))

    # Configure the layout for the visualization
    fig.update_layout(
        title='Minimum Spanning Tree (MST)',
        scene=dict(
            xaxis=dict(title='Px', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            yaxis=dict(title='Py', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            zaxis=dict(title='Pz', backgroundcolor='white', gridcolor='lightgrey', showbackground=True),
            aspectmode='data'  # Ensure correct proportions between axes
        ),
        margin=dict(l=10, r=10, b=10, t=50),
        height=800  # Increase the plot size
    )

    # Display the plot
    fig.show()

# %%
def label_segments(MST, df, start_node=0):
    # Identify bifurcations (nodes with degree > 2)
    bifurcations = [node for node, degree in MST.degree() if degree > 2]

    # Initialize labels for all nodes
    num_nodes = len(df)
    labels = np.zeros(num_nodes, dtype=int)
    current_label = 1

    # Traverse the MST and assign segment labels
    visited = set()
    stack = [(start_node, current_label)]

    while stack:
        node, label = stack.pop()
        if node in visited:
            continue
        visited.add(node)
        labels[node] = label

        neighbors = list(MST.neighbors(node))
        for neighbor in neighbors:
            if neighbor not in visited:
                if neighbor in bifurcations:
                    current_label += 1  # New label at bifurcation
                    stack.append((neighbor, current_label))
                else:
                    stack.append((neighbor, label))

    # Add labels back to the dataframe
    df['Branch ID'] = labels

    return df

# %%
def bifurcations_labeling(MST, df, start_node=0):
    # Identify bifurcations (nodes with degree > 2)
    bifurcations = [node for node, degree in MST.degree() if degree > 2]

    # Initialize labels for all nodes
    num_nodes = len(df)
    labels = np.zeros(num_nodes, dtype=int)
    current_label = 1

    # Traverse the MST and assign segment labels
    visited = set()
    stack = [(start_node, current_label)]

    while stack:
        node, label = stack.pop()
        if node in visited:
            continue
        visited.add(node)
        labels[node] = label

        neighbors = list(MST.neighbors(node))
        unvisited_neighbors = [n for n in neighbors if n not in visited]

        if node in bifurcations:
            # Assign new labels to each branch at the bifurcation
            for neighbor in unvisited_neighbors:
                current_label += 1
                stack.append((neighbor, current_label))
        else:
            for neighbor in unvisited_neighbors:
                stack.append((neighbor, label))

    # Add labels back to the dataframe
    df['Branch ID'] = labels

    return df

# %% [markdown]
# ## **NORMAL 1**

# %% [markdown]
# ### **Execution - RCA Normal 1**

# %%
df_rca_n1 = parse_and_export_centerlines(file_path_rca_n1)
df_rca_n1.head()
# Out:
#    Branch ID        Px        Py       Pz      Tx      Ty      Tz      Nx  \
# 0         16  150.4411  124.7483  28.0525 -0.8410  0.5269 -0.1234  0.1021
# 1         16  149.9095  125.0840  27.9798 -0.8389  0.5338 -0.1063  0.1176
# 2         16  149.3632  125.4346  27.9166 -0.8358  0.5421 -0.0866  0.1640
# 3         16  148.7591  125.8320  27.8633 -0.8298  0.5549 -0.0590  0.2200
# 4         16  148.1571  126.2426  27.8321 -0.8196  0.5723 -0.0249  0.2893
#
#        Ny      Nz  ...     BNz    Dfit    Dmin    Dmax       C      Dh  \
# 0  0.3784  0.9200  ... -0.3720  0.4566  0.1851  0.7793     NaN  0.3867
# 1  0.3686  0.9221  ... -0.3720  0.9324  0.2362  1.5503  0.0292  0.8461
# 2  0.3971  0.9030  ... -0.4208  1.2609  0.5736  2.0474  0.0373  1.1644
# 3  0.4225  0.8792  ... -0.4727  1.1607  0.8701  1.4998  0.0482  1.0757
# 4  0.4510  0.8443  ... -0.5352  1.1610  0.6509  1.5376  0.0604  1.0726
#
#        Xh     Scf    Area       E
# 0  0.4962  1.5989  0.1546  0.6182
# 1  0.5458  3.1222  0.6604  0.8026
# 2  0.5687  4.1918  1.2202  0.6242
# 3  0.7172  3.8404  1.0327  0.7187
# 4  0.6976  3.8314  1.0274  0.7226
#
# [5 rows x 22 columns]

# %%
df_rca_n1 = clean_dataframe(df_rca_n1)
df_rca_n1
# Out:
#            Px        Py       Pz
# 0    150.4411  124.7483  28.0525
# 1    149.9095  125.0840  27.9798
# 2    149.3632  125.4346  27.9166
# 3    148.7591  125.8320  27.8633
# 4    148.1571  126.2426  27.8321
# ..        ...       ...      ...
# 1         10  165.5281  105.5010  77.7533 -0.6262  0.2326  0.7441 -0.3115
# 2         10  165.3429  105.5610  77.9707 -0.6432  0.1762  0.7451 -0.2660
# 3         10  165.1206  105.6082  78.2242 -0.6623  0.0971  0.7429 -0.2025
# 4         10  164.8774  105.6258  78.4921 -0.6787 -0.0041  0.7344 -0.1182
#
#        Ny      Nz  ...     BNz    Dfit    Dmin    Dmax       C      Dh  \
# 0 -0.9367  0.0723  ...  0.6671  0.9580  0.5374  1.4355     NaN  0.8015
# 1 -0.9496  0.0347  ...  0.6671  1.3974  0.7427  1.9252  0.1859  1.1244
# 2 -0.9640 -0.0016  ...  0.6669  1.5941  0.7662  2.1823  0.2180  1.3420
# 3 -0.9779 -0.0528  ...  0.6673  1.4368  0.9247  1.8548  0.2609  1.2641
# 4 -0.9863 -0.1147  ...  0.6690  1.4504  0.9030  1.8502  0.3076  1.3192
#
#        Xh     Scf    Area       E
# 0  0.5584  3.3391  0.6691  0.8144
# 1  0.5841  5.2718  1.4820  0.5607
# 2  0.6150  5.7910  1.9429  0.6037
# 3  0.6815  5.1560  1.6294  0.2421
# 4  0.7130  4.8825  1.6102  0.7215
#
# [5 rows x 22 columns]

# %%
df_lca_n1 = clean_dataframe(df_lca_n1)
df_lca_n1
# Out:
#            Px        Py       Pz
# 0    165.6963  105.4312  77.5512
# 1    165.5281  105.5010  77.7533
# 2    165.3429  105.5610  77.9707
# 3    165.1206  105.6082  78.2242
# 4    164.8774  105.6258  78.4921
# ..        ...       ...      ...
# 901  123.9599  130.4967  91.7940
# 902  123.5791  130.2197  91.8576
# 903  123.1971  129.9483  91.9276
# 904  122.8180  129.6789  92.0056
# 905  122.4453  129.4075  92.0957
#
# [897 rows x 3 columns]

# %% [markdown]
# ##### **Minimmum Spannig Tree Graph**

# %%
MST_lca_n1 = calculate_mst(df_lca_n1)

# %%
visualize_mst(df_lca_n1, MST_lca_n1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="582a3912-cda2-4ac7-8a0a-545585fd4abe" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("582a3912-cda2-4ac7-8a0a-545585fd4abe")) {                    Plotly.newPlot(                        "582a3912-cda2-4ac7-8a0a-545585fd4abe",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"Edges","x":[165.6963,165.5281,null,165.5281,165.3429,null,165.3429,165.1206,null,165.1206,164.8774,null,164.8774,164.6284,null,164.6284,164.3856,null,164.3856,164.1564,null,164.1564,163.9439,null,163.9439,163.7467,null,163.7467,163.5604,null,163.5604,163.3793,null,163.3793,163.1976,null,163.1976,163.0113,null,163.0113,162.8185,null,162.8185,162.6199,null,162.6199,162.4182,null,162.4182,162.217,null,162.217,162.0202,null,162.0202,161.8305,null,161.8305,161.649,null,161.649,161.4751,null,161.4751,161.3065,null,161.3065,161.14,null,161.14,160.9724,null,160.9724,160.8015,null,160.8015,160.6262,null,160.6262,160.4472,null,160.4472,160.2664,null,160.2664,160.0864,null,160.0864,159.9098,null,159.9098,159.7381,null,159.7381,159.5711,null,159.5711,159.4071,null,159.4071,159.2428,null,159.2428,159.0741,null,159.0741,158.8972,null,158.
3483,82.5569,82.7698,82.9923,83.2265,83.4711,83.7214,83.9717,84.216,84.4504,84.6739,84.8886,85.0993,85.3117,85.5315,85.7623,86.0051,86.2581,86.5168,86.7753,87.0275,87.2681,87.4936,87.7023,87.8946,88.0719,88.2361,88.3892,88.5328,88.6678,88.795,88.9149,89.0282,89.136,89.2398,89.3413,89.4423,89.5447,89.6505,89.7617,89.8803,90.009,90.1502,90.3065,90.4796,90.6702,90.8773,91.0979,91.3273,91.5597,91.7891,92.0101,92.2192,92.4153,92.5994,92.7746,92.945,93.1142,93.2847,93.4565,93.6279,93.7951,93.9536,94.0992,94.2295,94.3443,94.4456,94.5376,94.6253,94.7138,94.8067,94.9057,95.0105,95.1192,95.229,95.337,95.4414,95.5415,95.6378,95.7313,95.8226,95.9115,95.9959,96.0722,96.1358,96.1817,96.2417],"type":"scatter3d"},{"marker":{"color":0.1,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5 ...

# %% [markdown]
# ## **NORMAL 7**

# %% [markdown]
# ### **Execution - RCA Normal 7**

# %%
df_rca_n7 = parse_and_export_centerlines(file_path_rca_n7)
df_rca_n7.head()
# Out:
#    Branch ID       Px       Py       Pz      Tx      Ty      Tz      Nx  \
# 0          1  85.5587  89.4809  88.5482 -0.9627 -0.2567 -0.0857  0.2335
# 1          1  85.0071  89.3207  88.5016 -0.9512 -0.2990 -0.0759  0.2765
# 2          1  84.4266  89.1223  88.4583 -0.9350 -0.3488 -0.0644  0.3290
# 3          1  83.7701  88.8501  88.4178 -0.9064 -0.4197 -0.0486  0.4032
# 4          1  83.1066  88.5028  88.3885 -0.8586 -0.5118 -0.0288  0.4993
#
#        Ny      Nz  ...     BNz    Dfit    Dmin    Dmax       C      Dh  \
# 0 -0.9480  0.2164  ...  0.9725  1.3918  0.9133  2.1490     NaN  1.2213
# 1 -0.9355  0.2200  ...  0.9725  2.0776  1.3993  2.8398  0.0780  1.8308
# 2 -0.9208  0.2095  ...  0.9757  2.9739  1.9300  4.7210  0.0963  2.3312
# 3 -0.8936  0.1974  ...  0.9791  3.5464  2.5297  5.0184  0.1232  3.1165
# 4 -0.8476  0.1795  ...  0.9833  4.0744  3.2805  5.1569  0.1592  3.9189
#
#        Xh      Scf     Area       E
# 0  0.5683   4.7051   1.4366  0.8269
# 1  0.6447   7.0335   3.2193  0.7766
# 2  0.4938  10.5551   6.1514  0.8334
# 3  0.6210  11.9780   9.3325  0.7973
# 4  0.7599  13.2049  12.9372  0.5225
#
# [5 rows x 22 columns]

# %%
df_rca_n7 = clean_dataframe(df_rca_n7)
df_rca_n7
# Out:
#           Px       Py       Pz
# 0    85.5587  89.4809  88.5482
# 1    85.0071  89.3207  88.5016
# 2    84.4266  89.1223  88.4583
# 3    83.7701  88.8501  88.4178
# 4    83.1066  88.5028  88.3885
# ..       ...      ...      ...
# 312  68.0813  88.6793  29.1486
# 313  67.8826  88.3532  28.9623
# 314  67.7027  88.0556  28.7639
# 315  67.5542  87.8073  28.5812
# 316  67.4480  87.6284  28.4411
#
# [316 rows x 3 columns]

# %% [markdown]
# ##### **Minimmum Spannig Tree Graph**

# %%
MST_rca_n7 = calculate_mst(df_rca_n7)

# %%
visualize_mst(df_rca_n7, MST_rca_n7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
292,null,67.6292,67.5445,null,67.5445,67.4564,null,67.4564,67.3765,null,67.3765,67.3301,null,67.3301,67.448,null,67.3301,67.3003,null,67.3003,67.3346,null,67.3346,67.4332,null,67.4332,67.6021,null,67.6021,67.8402,null,67.8402,68.1401,null,68.1401,68.4898,null,68.4898,68.8752,null,68.8752,69.2834,null,69.2834,69.7052,null,69.7052,70.1361,null,70.1361,70.576,null,70.576,71.0277,null,71.0277,71.4942,null,71.4942,71.9758,null,71.9758,72.4684,null,72.4684,72.9631,null,72.9631,73.4479,null,73.4479,73.9098,null,73.9098,74.3393,null,74.3393,74.7324,null,74.7324,75.0935,null,75.0935,75.4352,null,75.4352,75.7759,null,75.7759,76.1373,null,76.1373,76.5391,null,76.5391,76.9957,null,76.9957,77.5133,null,77.5133,78.0885,null,78.0885,78.7101,null,78.7101,79.3611,null,79.3611,80.0226,null,80.0226,80.6772,null,80.6772,81.3117,null,81.3117,81.9186,null,81.9186,82.4958,null,82.4958,83.0457,null,83.0457,83.5729,null,83.5729,84.0831,null,84.0831,84.5812,null,84.5812,85.0716,null,85.0716,85.557 ...

# %% [markdown]
# #### **Bifurcations algotithm**

# %%
df_rca_n7_labelled = bifurcations_labeling(MST_rca_n7, df_rca_n7)
df_rca_n7_labelled
# Out:
#           Px       Py       Pz  Branch ID
# 0    85.5587  89.4809  88.5482          1
# 1    85.0071  89.3207  88.5016          1
# 2    84.4266  89.1223  88.4583          1
# 3    83.7701  88.8501  88.4178          1
# 4    83.1066  88.5028  88.3885          1
# ..       ...      ...      ...        ...
# 312  68.0813  88.6793  29.1486          2
# 313  67.8826  88.3532  28.9623          2
# 314  67.7027  88.0556  28.7639          2
# 315  67.5542  87.8073  28.5812          2
# 316  67.4480  87.6284  28.4411          2
#
# [316 rows x 4 columns]

# %%
# Print unique values of the column
unique_values = df_rca_n7_labelled['Branch ID'].unique()
print(unique_values)
# Out:
# [1 3 2]

# %%
visualize_segments(df_rca_n7_labelled)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b40cbfe8-653f-4ee0-b314-a3ef0551633b" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b40cbfe8-653f-4ee0-b314-a3ef0551633b")) {                    Plotly.newPlot(                        "b40cbfe8-653f-4ee0-b314-a3ef0551633b",                        [{"marker":{"color":0.0,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"size":3},"mode":"markers","name":"Branch 1","x":[85.5587,85.0071,84.4266,83.7701,83.1066,82.492,81.96,81.5188,81.1538,80.835,80.5275,80.2008,79.8368,79.4326,78.9997,78.5584,78.1316,77.7376,77.3858,77.0747,76.794,76.528,76.2611,75.9821,75.6872,75.38,75.0703,74.7703,74.4913,74.2403,74.0187,73.8227,73.6445,73.4752,73.3069,73.1348,72.9574,72.7763,72.5948,72.4164,72.2432,72.0759,71.9128,71.7514,71.5884,71.4211,71.2477,71.0673,70.8797,70.6854,70.4852,70.2797,70.0702,69.8582,69.6459,69.4355,69.2294,69.0292,68.835,68.6456,68.4582,68.2698,68.0773,67.8793,67.6768,67.4729,67.2727,67.0819,66.9052,66.7453,66.6022,66.4728,66.3524,66.2357,66.1192,66.0014,65.8843,65.7722,65
"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555 ...

# %% [markdown]
# ### **Execution - LCA Normal 7**

# %%
df_lca_n7 = parse_and_export_centerlines(file_path_lca_n7)
df_lca_n7.head()
# Out:
#    Branch ID        Px        Py       Pz      Tx      Ty      Tz      Nx  \
# 0          0  108.2599  119.5730  91.2165  0.9665 -0.2565 -0.0073  0.1838
# 1          0  108.5385  119.5187  91.1969  0.9838 -0.1225 -0.1307  0.0046
# 2          0  108.7702  119.5018  91.1551  0.9759 -0.0337 -0.2155 -0.1377
# 3          0  109.0604  119.4995  91.0814  0.9680 -0.0106 -0.2508  0.0993
# 4          0  109.4093  119.4893  90.9940  0.9703 -0.0404 -0.2387  0.0225
#
#        Ny      Nz  ...     BNz    Dfit    Dmin     Dmax       C      Dh  \
# 0  0.7119 -0.6778  ...  0.7352  4.0877  3.5013   6.0208     NaN  3.8351
# 1  0.7467 -0.6651  ...  0.7352  6.6115  3.3573  11.1789  0.6499  5.2093
# 2  0.6709 -0.7287  ...  0.6501  5.7747  3.3146  10.1031  0.3994  4.8978
# 3 -0.9016  0.4211  ... -0.8717  5.5881  3.0409  10.4102  0.1263  4.8086
# 4 -0.9666  0.2553  ... -0.9370  5.7847  2.5912  12.1272  0.0537  4.8027
#
#        Xh      Scf     Area       E
# 0  0.6370  13.3763  12.8247  0.6743
# 1  0.4660  23.1192  30.1087  0.9279
# 2  0.4848  19.6368  24.0441  0.8955
# 3  0.4619  18.9056  22.7275  0.8829
# 4  0.3960  19.9101  23.9056  0.8908
#
# [5 rows x 22 columns]

# %%
df_lca_n7 = clean_dataframe(df_lca_n7)
df_lca_n7
# Out:
#            Px        Py       Pz
# 0    108.2599  119.5730  91.2165
# 1    108.5385  119.5187  91.1969
# 2    108.7702  119.5018  91.1551
# 3    109.0604  119.4995  91.0814
# 4    109.4093  119.4893  90.9940
# ..        ...       ...      ...
# 841   97.7172  143.5526  48.9518
# 842   97.5046  143.3270  48.4060
# 843   97.3041  143.1103  47.9115
# 844   97.1332  142.9231  47.5020
# 845   96.9752  142.7485  47.1321
#
# [836 rows x 3 columns]

# %% [markdown]
# ##### **Minimmum Spannig Tree Graph**

# %%
MST_lca_n7 = calculate_mst(df_lca_n7)

# %%
visualize_mst(df_lca_n7, MST_lca_n7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7f4c038e-ac1f-4ec6-a07a-79b34cac5222" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f4c038e-ac1f-4ec6-a07a-79b34cac5222")) {                    Plotly.newPlot(                        "7f4c038e-ac1f-4ec6-a07a-79b34cac5222",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"Edges","x":[108.2599,108.5385,null,108.2599,108.1128,null,108.5385,108.7702,null,108.5385,108.5049,null,108.7702,109.0604,null,109.0604,109.4093,null,109.4093,109.7919,null,109.7919,110.1842,null,110.1842,110.5662,null,110.5662,110.9241,null,110.9241,111.2502,null,111.2502,111.543,null,111.543,111.8058,null,111.8058,112.0443,null,112.0443,112.2652,null,112.2652,112.4748,null,112.4748,112.6777,null,112.6777,112.8771,null,112.8771,113.0749,null,113.0749,113.2729,null,113.2729,113.4726,null,113.4726,113.6766,null,113.6766,113.8879,null,113.8879,114.1095,null,114.1095,114.3442,null,114.3442,114.5934,null,114.5934,114.8567,null,114.8567,115.132,null,115.132,115.416,null,115.416,115.7047,null,115.7047,115.9945,null,115.9945,116.2834,null,116.2834,116.5712,null,116
.3584,121.3419,121.332,121.3282,121.3318,121.346,121.3749,121.4236,121.4964,121.5967,121.7255,121.8819,122.0627,122.2635,122.4795,122.7067,122.9427,123.1871,123.442,123.7105,123.9964,124.3024,124.6285,124.9713,125.323,125.6715,126.0012,126.2945,126.5338,126.7471],"z":[91.1551,91.0814,90.994,90.9016,90.8145,90.7434,90.6985,90.688,90.717,90.7864,90.8931,91.0297,91.1862,91.351,91.5136,91.6654,91.8017,91.9218,92.0287,92.1283,92.2272,92.3313,92.4439,92.565,92.691,92.8152,92.9294,93.0256,93.0972,93.1408,93.1563,93.1469,93.1182,93.0764,93.0274,92.9751,92.9209,92.8638,92.8006,92.727,92.6389,92.5333,92.4088,92.2657,92.1056,91.9305,91.7422,91.5415,91.3275,91.0986,90.8524,90.5868,90.3013,89.9971,89.6781,89.35,89.0203,88.6967,88.3867,88.096,87.8288,87.5867,87.3701,87.1779,87.0085,86.8605, ...

# %% [markdown]
# ## **DISEASED 7**

# %% [markdown]
# ### **Execution - RCA Diseased 7**

# %%
df_rca_d7 = parse_and_export_centerlines(file_path_rca_d7)
df_rca_d7.head()
# Out:
#    Branch ID        Px        Py       Pz      Tx      Ty      Tz      Nx  \
# 0          0  142.4291  101.9354  38.8485 -0.8962  0.4216 -0.1378  0.2698
# 1          0  141.9711  102.1537  38.7798 -0.8928  0.4311 -0.1306  0.2809
# 2          0  141.4801  102.3940  38.7101 -0.8891  0.4411 -0.1218  0.2539
# 3          0  140.9089  102.6818  38.6355 -0.8851  0.4525 -0.1090  0.2081
# 4          0  140.3051  102.9948  38.5666 -0.8818  0.4626 -0.0915  0.1104
#
#        Ny      Nz  ...     BNz    Dfit    Dmin    Dmax       C      Dh  \
# 0  0.7648  0.5850  ... -0.7992  0.7898  0.4322  1.0254     NaN  0.6824
# 1  0.7595  0.5867  ... -0.7992  0.7911  0.3724  1.2606  0.0242  0.6898
# 2  0.6969  0.6707  ... -0.7316  1.0602  0.5492  2.0556  0.0261  0.9314
# 3  0.5942  0.7770  ... -0.6200  1.2583  0.9344  2.1455  0.0287  1.0505
# 4  0.3911  0.9137  ... -0.3959  1.4088  1.2336  1.7459  0.0317  1.3479
#
#        Xh     Scf    Area       E
# 0  0.6655  2.7905  0.4760  0.6980
# 1  0.5472  2.8340  0.4887  0.3149
# 2  0.4531  3.6030  0.8390  0.7985
# 3  0.4896  4.4687  1.1736  0.7550
# 4  0.7721  4.5750  1.5417  0.4940
#
# [5 rows x 22 columns]

# %%
df_rca_d7 = clean_dataframe(df_rca_d7)
df_rca_d7
# Out:
#            Px        Py       Pz
# 0    142.4291  101.9354  38.8485
# 1    141.9711  102.1537  38.7798
# 2    141.4801  102.3940  38.7101
# 3    140.9089  102.6818  38.6355
# 4    140.3051  102.9948  38.5666
# ..        ...       ...      ...
# 401  108.0949   89.3446  34.9859
# 402  108.3885   88.9726  34.9874
# 403  108.6563   88.6091  34.9921
# 404  108.8796   88.2897  34.9986
# 405  109.0828   87.9872  35.0064
#
# [404 rows x 3 columns]

# %% [markdown]
# ##### **Minimmum Spannig Tree Graph**

# %%
MST_rca_d7 = calculate_mst(df_rca_d7)

# %%
visualize_mst(df_rca_d7, MST_rca_d7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
# 2          1  113.6132  103.1759  109.8462 -0.9267 -0.2260 -0.3002  0.3605
# 3          1  111.8039  102.6826  109.0206 -0.8331 -0.2137 -0.5101  0.4144
# 4          1  110.2861  102.3578  107.8257 -0.7061 -0.1165 -0.6984  0.6060
#
#        Ny      Nz  ...     BNz    Dfit    Dmin    Dmax       C      Dh  \
# 0  0.2060  0.9321  ... -0.2549  5.1939  3.4039  9.1903     NaN  4.0982
# 1  0.2145  0.9423  ... -0.2549  4.3008  3.7126  5.0639  0.0207  3.9899
# 2 -0.3100 -0.8797  ...  0.3687  4.2543  3.5637  5.0379  0.1121  3.7533
# 3  0.3696 -0.8317  ... -0.2194  5.2090  4.4574  6.1512  0.1285  4.5990
# 4  0.4107 -0.6812  ... -0.2194     NaN     NaN     NaN     NaN     NaN
#
#        Xh      Scf     Area       E
# 0  0.4459  19.0982  19.5668  0.8484
# 1  0.7879  14.4542  14.4177  0.5552
# 2  0.7450  15.0404  14.1127  0.6047
# 3  0.7476  18.4221  21.1806  0.4395
# 4     NaN      NaN      NaN     NaN
#
# [5 rows x 22 columns]

# %%
df_lca_d7 = clean_dataframe(df_lca_d7)
df_lca_d7
# Out:
#            Px        Py        Pz
# 0    117.5563  103.9986  110.8087
# 1    115.5842  103.5882  110.3172
# 2    113.6132  103.1759  109.8462
# 3    111.8039  102.6826  109.0206
# 4    110.2861  102.3578  107.8257
# ..        ...       ...       ...
# 606  154.6442   67.3693   87.4326
# 607  154.7963   67.1634   87.2352
# 608  154.9400   66.9529   87.0837
# 609  155.0642   66.7602   86.9784
# 610  155.1806   66.5714   86.8991
#
# [602 rows x 3 columns]

# %% [markdown]
# ##### **Minimmum Spannig Tree Graph**

# %%
MST_lca_d7 = calculate_mst(df_lca_d7)

# %%
visualize_mst(df_lca_d7, MST_lca_d7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3dbee07e-26e2-47cc-afaf-ca732a215c6e" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dbee07e-26e2-47cc-afaf-ca732a215c6e")) {                    Plotly.newPlot(                        "3dbee07e-26e2-47cc-afaf-ca732a215c6e",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"Edges","x":[117.5563,117.6612,null,117.5563,118.0991,null,117.5563,115.5842,null,115.5842,113.6132,null,113.6132,111.8039,null,111.8039,110.2861,null,152.5448,152.2564,null,152.2564,151.9533,null,151.9533,151.6105,null,151.6105,151.2625,null,151.2625,150.9358,null,150.9358,150.6439,null,150.6439,150.3866,null,150.3866,150.1531,null,150.1531,149.9268,null,149.9268,149.6932,null,149.6932,149.4455,null,149.4455,149.1889,null,149.1889,148.9417,null,148.9417,148.7316,null,148.7316,148.5909,null,148.5909,148.5482,null,148.5482,148.622,null,148.622,148.8156,null,148.8156,149.1154,null,149.1154,149.4927,null,149.4927,149.909,null,149.909,150.3228,null,150.3228,150.6972,null,150.6972,151.0055,null,151.0055,151.235,null,151.235,151.3868,null,151.3868,151.4735,null,151.4735,151.5139,null,151.5139,151.5275,null,151.5275,151.5293,null,151.5293,151.5268,null,151.5268,151.5184,null,151.5184,151.4949,null,151.4949,151.4428,null,151.4428,151.3482,null,151.3482,151.2002,null,151.2002,150.9944,null,150
# %% [markdown]
# ## **DISEASED 9**

# %% [markdown]
# ### **Execution - RCA Diseased 9**

# %%
df_rca_d9 = parse_and_export_centerlines(file_path_rca_d9)
df_rca_d9.head()
# Out:
#    Branch ID       Px        Py       Pz      Tx      Ty      Tz      Nx  \
# 0          4  93.2438  127.3554  32.7727 -0.2171  0.9538  0.2076  0.9662
# 1          4  93.1850  127.7816  32.8710 -0.0474  0.9705  0.2364  0.9892
# 2          4  93.1918  128.1071  32.9542  0.0921  0.9608  0.2615  0.9688
# 3          4  93.2544  128.4827  33.0637  0.1814  0.9408  0.2863  0.2653
# 4          4  93.3431  128.9215  33.2028  0.2070  0.9283  0.3090  0.8134
#
#        Ny      Nz  ...     BNz    Dfit    Dmin     Dmax       C      Dh  \
# 0  0.1797  0.1848  ... -0.9606  3.5249  2.4634   5.9066     NaN  2.8607
# 1  0.0127  0.1463  ... -0.9606  4.3220  2.6934   7.9420  0.3944  2.8088
# 2 -0.1471  0.1992  ... -0.9444     NaN  2.3501  26.0578  0.4566  2.5180
# 3 -0.3272  0.9070  ... -0.3090  3.0845  1.1590   6.5214  0.0440  1.8638
# 4 -0.3388  0.4728  ... -0.8252  2.3993  1.6105   3.1766  0.1194  2.1849
#
#        Xh      Scf     Area       E
# 0  0.4843  14.0066  10.0171  0.7079
# 1  0.3537  18.7730  13.1823  0.8406
# 2  0.0966  39.3249  24.7552  0.9783
# 3  0.2858  15.6600   7.2969  0.8409
# 4  0.6878   8.1158   4.4330  0.5677
#
# [5 rows x 22 columns]

# %%
df_rca_d9 = clean_dataframe(df_rca_d9)
df_rca_d9
# Out:
#           Px        Py        Pz
# 0    93.2438  127.3554   32.7727
# 1    93.1850  127.7816   32.8710
# 2    93.1918  128.1071   32.9542
# 3    93.2544  128.4827   33.0637
# 4    93.3431  128.9215   33.2028
# ..       ...       ...       ...
# 504  89.5781  111.5224  113.7899
# 505  89.6284  112.0969  113.8226
# 506  89.8562  112.6161  113.6975
# 507  90.0840  113.1352  113.5725
# 508  90.3118  113.6544  113.4474
#
# [507 rows x 3 columns]

# %% [markdown]
# ##### **Minimmum Spannig Tree Graph**

# %%
MST_rca_d9 = calculate_mst(df_rca_d9)

# %%
visualize_mst(df_rca_d9, MST_rca_d9)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="95b2d670-f0ab-4e2f-ae15-c55456fdbcce" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95b2d670-f0ab-4e2f-ae15-c55456fdbcce")) {                    Plotly.newPlot(                        "95b2d670-f0ab-4e2f-ae15-c55456fdbcce",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":
# %% [markdown]
# #### **Bifurcations algotithm**

# %%
df_rca_d9_labelled = bifurcations_labeling(MST_rca_d9, df_rca_d9)
df_rca_d9_labelled
# Out:
#           Px        Py        Pz  Branch ID
# 0    93.2438  127.3554   32.7727          1
# 1    93.1850  127.7816   32.8710          2
# 2    93.1918  128.1071   32.9542          2
# 3    93.2544  128.4827   33.0637          2
# 4    93.3431  128.9215   33.2028          2
# ..       ...       ...       ...        ...
# 504  89.5781  111.5224  113.7899          3
# 505  89.6284  112.0969  113.8226          3
# 506  89.8562  112.6161  113.6975          3
# 507  90.0840  113.1352  113.5725          3
# 508  90.3118  113.6544  113.4474          3
#
# [507 rows x 4 columns]

# %%
# Print unique values of the column
unique_values = df_rca_d9_labelled['Branch ID'].unique()
print(unique_values)
# Out:
# [1 2 4 3]

# %%
visualize_segments(df_rca_d9_labelled)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bf36a120-39fb-4dec-a50a-040d224180a0" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf36a120-39fb-4dec-a50a-040d224180a0")) {                    Plotly.newPlot(                        "bf36a120-39fb-4dec-a50a-040d224180a0",                        [{"marker":{"color":0.0,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"size":3},"mode":"markers","name":"Branch 1","x":[93.2438],"y":[127.3554],"z":[32.7727],"type":"scatter3d"},{"marker":{"color":0.3333333333333333,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"size":3},"mode":"markers","name":"Branch 2","x":[93.185,93.1918,93.2544,93.3431,93.4604,93.6076,93.784,93.9869,94.2112,94.4504,94.6972,94.9443,95.1858,95.4173,95.6371,95.8458,96.0459,96.2415,96.4373,96.6374,96.8454,97.0629,97.2903,97.5262,97.7684,98.0136,98.2589,98.5013,98.7386,98.9692,99.1919,99.4064,99.6122,99.8094,99.9981,100.1791,100.3532,100.5224,100.6888,100.8553,101.0249,101.2,101.3822,101.5715,101.7661,101.962,102.1537,102.3345,102.4972,102.6355,102.7442,102.8206,102.8641,102.8766,102.8619,102.8249,102.7712,102.7061,102.6343,102.5598,102.4863,102.4174,102.3573,102.3113,102.2861,102.2893,102.3294,102.4141,102.5503,102.7418,102.9895,103.2907,103.639,104.0254,104.4392,104.8695,105.3062,105.7414,106.17,106.5899,107.0013,107.4066,107.8085,108.2102,108.6136,109.0193,109.4267,109.8341,110.2393,110.6404,111.0362,111.4268,111.8138,112.1996,112.5877,112.9813,113.3833,113.7953,114.2176,114.6488,115.0861,115.5256,115.9626,116.3926,116.811,117.2141,117.5988,117.9631,118.3057,118.6257,118.9229,119.1969,119.447,119.6724,119.872,120.0444,120.1883,120.303,120.3892,120.449,120.4872,120.511,120.5301,120.5565,120.6035,120.6844,120.8112,120.993,121.2346,121.5363,121.8928,122.2947,122.7291,123.1819,123.6393,124.0902,124.5273,124.948,125.3544,125.7521,126.1488,126.5522,126.9684,127.3999,127.8452,128.2988,128.7523,129.1956,129.6194,130.0166,130.3839,130.7225,131.0377,131.3381,131.6