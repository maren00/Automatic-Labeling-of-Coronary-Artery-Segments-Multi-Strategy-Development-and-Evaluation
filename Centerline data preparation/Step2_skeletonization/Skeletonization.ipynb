# %% [markdown]
# ## **Skeletonization**

# %% [markdown]
# The following code computes the voxel-centerline (skeletonization) per case and segment label segmentation.
#
# A global skeleton is computed to preserve continuity, and then intersected voxel-wise with each label mask.
#
# This ensures anatomically labeled centerlines without losing structural connectivity.

# %% [markdown]
# ### **Imports and Installs**

# %%
# !pip install scikit-image==0.18.3
# Out:
# Collecting scikit-image==0.18.3
#   Using cached scikit-image-0.18.3.tar.gz (29.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (1.26.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (1.14.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (3.10.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (3.4.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (11.1.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (2.37.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.18.3) (2025.2.18)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.18.3)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.3) (1.17.0)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.4 MB/s eta 0:00:00
# Building wheels for collected packages: scikit-image
#   Building wheel for scikit-image (pyproject.toml) ... done
#   Created wheel for scikit-image: filename=scikit_image-0.18.3-cp311-cp311-linux_x86_64.whl size=37878510 sha256=964ba5b1dcc2465bd55383a78ddc96f32ddc95c983780aa5ada233fad31c8961
#   Stored in directory: /root/.cache/pip/wheels/e3/f1/e0/18ca2948c8e8670f1f357bb1704d22638ea3cb247f77fe0ce2
# Successfully built scikit-image
# Installing collected packages: PyWavelets, scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
# Successfully installed PyWavelets-1.8.0 scikit-image-0.18.3

# %%
import os
import nibabel as nib
import numpy as np
from skimage.morphology import skeletonize_3d

# %% [markdown]
# ### **Google Drive connection**

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Upload files**

# %%
# Define input and output directories
input_multilabel_dir = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/Skeletonization/GT_multilabel'
input_binary_dir = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/Skeletonization/GT'
output_base_dir = '/content/drive/Shared drives/TFGs Coronarias 2024_25/Maren/Data/Skeletonization/Processed'

# %% [markdown]
# ### **Functions**

# %%
def process_multilabel_case(multilabel_path, output_case_dir):
    """
    Process a single multilabel case by:
    1. Creating the skeletonization of the entire multilabel.
    2. Extracting and saving binary masks for each label (1-19).
    3. Calculating the skeletons for each label.

    Parameters:
        multilabel_path (str): Path to the input multilabel .nii.gz file.
        output_case_dir (str): Path to the output directory for this case.
    """
    # Load the multilabel image
    multilabel_img = nib.load(multilabel_path)
    multilabel_data = multilabel_img.get_fdata()

    # Ensure the data is in binary format for skeletonization
    binary_mask = (multilabel_data > 0).astype(np.uint8)

    # Perform 3D skeletonization for the entire mask
    skeleton = skeletonize_3d(binary_mask)

    # Save the skeleton for the entire multilabel
    skeleton_img = nib.Nifti1Image(skeleton.astype(np.uint8), multilabel_img.affine, multilabel_img.header)
    skeleton_path = os.path.join(output_case_dir, 'skeleton.nii.gz')
    nib.save(skeleton_img, skeleton_path)
    print(f"Saved skeleton for the entire multilabel at: {skeleton_path}")

    # Process and save skeletons for each label (1-19)
    for label in range(1, 20):
        label_mask = (multilabel_data == label).astype(np.uint8)
        label_skeleton = skeletonize_3d(label_mask)

        # Save the skeleton for the current label
        label_skeleton_img = nib.Nifti1Image(label_skeleton.astype(np.uint8), multilabel_img.affine, multilabel_img.header)
        label_skeleton_path = os.path.join(output_case_dir, f'label_{label}_skeleton.nii.gz')
        nib.save(label_skeleton_img, label_skeleton_path)
        print(f"Saved skeleton for label {label} at: {label_skeleton_path}")

def process_binary_case(binary_path, output_case_dir):
    """
    Process a single binary case by creating its 3D skeletonization.

    Parameters:
        binary_path (str): Path to the input binary .nii.gz file.
        output_case_dir (str): Path to the output directory for this case.
    """
    # Load the binary image
    binary_img = nib.load(binary_path)
    binary_data = binary_img.get_fdata()

    # Ensure the mask is binary
    binary_mask = (binary_data > 0).astype(np.uint8)

    # Perform 3D skeletonization
    skeleton = skeletonize_3d(binary_mask)

    # Save the skeletonized binary image
    skeleton_img = nib.Nifti1Image(skeleton.astype(np.uint8), binary_img.affine, binary_img.header)
    skeleton_path = os.path.join(output_case_dir, 'binary_skeleton.nii.gz')
    nib.save(skeleton_img, skeleton_path)
    print(f"Saved skeleton for binary mask at: {skeleton_path}")

def process_label_intersections(skeleton_path, multilabel_path, output_case_dir):
    """
    Computes binary intersections between the skeleton and each label (1-19)
    in the multilabel image and saves results for each label.

    Parameters:
        skeleton_path (str): Path to the skeleton .nii.gz file.
        multilabel_path (str): Path to the multilabel .nii.gz file.
        output_case_dir (str): Path to the output directory for this case.
    """
    # Load skeleton and multilabel images
    skeleton_img = nib.load(skeleton_path)
    multilabel_img = nib.load(multilabel_path)

    skeleton_data = skeleton_img.get_fdata()  # Skeleton is binary (0/1)
    multilabel_data = multilabel_img.get_fdata()  # Labels range from 0 to 19

    # Ensure skeleton is binary
    skeleton_binary = (skeleton_data == 1).astype(np.uint8)

    # Process and save intersections for each label (1-19)
    for label in range(1, 20):
        label_mask = (multilabel_data == label).astype(np.uint8)
        skeleton_label = (skeleton_binary & label_mask).astype(np.uint8)

        # Save the result
        label_intersection_img = nib.Nifti1Image(skeleton_label, skeleton_img.affine, skeleton_img.header)
        label_intersection_path = os.path.join(output_case_dir, f'label_{label}_intersection.nii.gz')
        nib.save(label_intersection_img, label_intersection_path)
        print(f"Saved intersection for label {label} at: {label_intersection_path}")

# %% [markdown]
# ### **Execution**

# %%
# Create the output base directory if it doesn't exist
os.makedirs(output_base_dir, exist_ok=True)

# Iterate through all files in the input directories
for file_name in os.listdir(input_multilabel_dir):
    if file_name.endswith('.nii.gz'):
        multilabel_path = os.path.join(input_multilabel_dir, file_name)

        # Create a directory for the current case
        case_name = os.path.splitext(os.path.splitext(file_name)[0])[0]  # Remove .nii.gz
        output_case_dir = os.path.join(output_base_dir, case_name)
        os.makedirs(output_case_dir, exist_ok=True)

        print(f"Processing multilabel case: {case_name}")
        process_multilabel_case(multilabel_path, output_case_dir)

        # Check if a corresponding binary file exists
        binary_path = os.path.join(input_binary_dir, file_name)
        if os.path.exists(binary_path):
            print(f"Processing binary case: {case_name}")
            process_binary_case(binary_path, output_case_dir)

            # Process intersections if both skeleton and multilabel exist
            skeleton_path = os.path.join(output_case_dir, 'binary_skeleton.nii.gz')
            process_label_intersections(skeleton_path, multilabel_path, output_case_dir)

print("Processing completed!")
# Out:
# Processing multilabel case: Diseased_7
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_19_skeleton.nii.gz
# Processing binary case: Diseased_7
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_7/label_19_intersection.nii.gz
# Processing multilabel case: Diseased_18
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_19_skeleton.nii.gz
# Processing binary case: Diseased_18
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_18/label_19_intersection.nii.gz
# Processing multilabel case: Diseased_9
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_19_skeleton.nii.gz
# Processing binary case: Diseased_9
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_9/label_19_intersection.nii.gz
# Processing multilabel case: Diseased_16
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_19_skeleton.nii.gz
# Processing binary case: Diseased_16
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_16/label_19_intersection.nii.gz
# Processing multilabel case: Normal_9
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_19_skeleton.nii.gz
# Processing binary case: Normal_9
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_9/label_19_intersection.nii.gz
# Processing multilabel case: Diseased_10
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_19_skeleton.nii.gz
# Processing binary case: Diseased_10
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_10/label_19_intersection.nii.gz
# Processing multilabel case: Diseased_4
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_19_skeleton.nii.gz
# Processing binary case: Diseased_4
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_4/label_19_intersection.nii.gz
# Processing multilabel case: Diseased_1
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_19_skeleton.nii.gz
# Processing binary case: Diseased_1
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_1/label_19_intersection.nii.gz
# Processing multilabel case: Normal_15
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_15/label_15_skeleton.nii.gz
# ...
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_19_skeleton.nii.gz
# Processing binary case: Diseased_17
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Diseased_17/label_19_intersection.nii.gz
# Processing multilabel case: Normal_8
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_19_skeleton.nii.gz
# Processing binary case: Normal_8
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_8/label_19_intersection.nii.gz
# Processing multilabel case: Normal_4
# Saved skeleton for the entire multilabel at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/skeleton.nii.gz
# Saved skeleton for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_1_skeleton.nii.gz
# Saved skeleton for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_2_skeleton.nii.gz
# Saved skeleton for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_3_skeleton.nii.gz
# Saved skeleton for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_4_skeleton.nii.gz
# Saved skeleton for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_5_skeleton.nii.gz
# Saved skeleton for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_6_skeleton.nii.gz
# Saved skeleton for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_7_skeleton.nii.gz
# Saved skeleton for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_8_skeleton.nii.gz
# Saved skeleton for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_9_skeleton.nii.gz
# Saved skeleton for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_10_skeleton.nii.gz
# Saved skeleton for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_11_skeleton.nii.gz
# Saved skeleton for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_12_skeleton.nii.gz
# Saved skeleton for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_13_skeleton.nii.gz
# Saved skeleton for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_14_skeleton.nii.gz
# Saved skeleton for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_15_skeleton.nii.gz
# Saved skeleton for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_16_skeleton.nii.gz
# Saved skeleton for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_17_skeleton.nii.gz
# Saved skeleton for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_18_skeleton.nii.gz
# Saved skeleton for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_19_skeleton.nii.gz
# Processing binary case: Normal_4
# Saved skeleton for binary mask at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/binary_skeleton.nii.gz
# Saved intersection for label 1 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_1_intersection.nii.gz
# Saved intersection for label 2 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_2_intersection.nii.gz
# Saved intersection for label 3 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_3_intersection.nii.gz
# Saved intersection for label 4 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_4_intersection.nii.gz
# Saved intersection for label 5 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_5_intersection.nii.gz
# Saved intersection for label 6 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_6_intersection.nii.gz
# Saved intersection for label 7 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_7_intersection.nii.gz
# Saved intersection for label 8 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_8_intersection.nii.gz
# Saved intersection for label 9 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_9_intersection.nii.gz
# Saved intersection for label 10 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_10_intersection.nii.gz
# Saved intersection for label 11 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_11_intersection.nii.gz
# Saved intersection for label 12 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_12_intersection.nii.gz
# Saved intersection for label 13 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_13_intersection.nii.gz
# Saved intersection for label 14 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_14_intersection.nii.gz
# Saved intersection for label 15 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_15_intersection.nii.gz
# Saved intersection for label 16 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_16_intersection.nii.gz
# Saved intersection for label 17 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_17_intersection.nii.gz
# Saved intersection for label 18 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_18_intersection.nii.gz
# Saved intersection for label 19 at: /content/drive/Shared drives/TFG Maren/Data/Skeletonization/Processed/Normal_4/label_19_intersection.nii.gz
# Processing completed!
